# %%
#necessary module
import os ; import sys
sys.path.append(os.getcwd()+"/Equantum")
#path to data
datapath="/scratch/zhaoyuha/Datas/EQuantum_data/dotgate_center_g/"
setuppath="/scratch/zhaoyuha/Datas/EQuantum_data/dotgate_center_g/setup/"
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as sl
import importlib
from scipy.interpolate import interp1d
from scipy.optimize import minimize_scalar, brentq

# %matplotlib widget

# %%
import fsc
importlib.reload(fsc)
from fsc import FSC

import EQsystem
importlib.reload(EQsystem)
from EQsystem import System

import poissonsolver
importlib.reload(poissonsolver)
# Out:
# <module 'poissonsolver' from '/scratch/zhaoyuha/Projects/EQuantum/EQuantum/Equantum/poissonsolver.py'>

# %%
import qbuilder
importlib.reload(qbuilder)
import poissonsolver
importlib.reload(poissonsolver)
import poissonsolver as psolver

# %%
import solvers
importlib.reload(solvers)
from solvers import local_solver

# %% [markdown]
# ## Define system

# %%
def density_function(z):
        spacing0 = 0.015 # spacing at r=0
        k = 0.  # spacing increases by 0.05 per unit distance
        return spacing0 + k * z

# %%
def density_function(z):
        spacing0 = 0.008 # spacing at r=0
        k = 0.2  # spacing increases by 0.05 per unit distance
        if abs(z)<3*spacing0:
            return spacing0   #define same lattice for the layers above/beneath quantum system, avoid oscillation due to the lattice mismatch
        else:
            return spacing0 + k * z

# %%
geoparams={"lattice_type": "square",   # or honeycomb_lattice, etc.
"box_size": ((-0.6, 0.6), (-0.45, 0.45), (-0.08, 0.08)),
"sampling_density_function": density_function,
"quantum_center": (0,0,0)     # optional, defaults to (0,0,0)
              }

# %%
geoparams={"lattice_type": "honeycomb",   # or honeycomb_lattice, etc.
"box_size": ((-0.6, 0.6), (-0.6, 0.6), (-0.08, 0.08)),
"sampling_density_function": density_function,
"quantum_center": (0,0,0)     # optional, defaults to (0,0,0)
              }

# %% [markdown]
# ## Initialize System

# %%
import os
import hashlib
import inspect

def get_geoparams_hash(params, *funcs):
    params_repr = {}
    for k, v in params.items():
        if callable(v):
            try:
                params_repr[k] = inspect.getsource(v).strip()
            except Exception:
                params_repr[k] = str(v)
        else:
            params_repr[k] = str(v)
            
    for f in funcs:
        try:
            params_repr[f.__name__] = inspect.getsource(f).strip()
        except Exception:
            pass
            
    # Sort keys for consistent hashing
    params_str = str(sorted(params_repr.items()))
    return hashlib.md5(params_str.encode()).hexdigest(), params_repr

current_hash, params_repr = get_geoparams_hash(geoparams, density_function)

hash_folder = os.path.join(setuppath, f"setup_{current_hash}")
hash_file = os.path.join(hash_folder, "geoparams_hash.txt")
sites_file = os.path.join(hash_folder, "sites.json")
readme_file = os.path.join(hash_folder, "README.txt")


generate_sites = True
if os.path.exists(hash_folder) and os.path.exists(sites_file) and os.path.exists(hash_file):
    with open(hash_file, "r") as f:
        saved_hash = f.read().strip()
    if saved_hash == current_hash:
        generate_sites = False
        print(f"Settings unchanged. Found existing setup in {hash_folder}. Skipping generation.")

if generate_sites:
    print(f"Generating new setup in {hash_folder}...")
    os.makedirs(hash_folder, exist_ok=True)
    syst=System(geoparams,assign_mat=False)
    syst.export_sites(filename=sites_file)
    with open(hash_file, "w") as f:
        f.write(current_hash)
    with open(readme_file, "w") as f:
        f.write("Parameter settings for this setup:")
        for k, v in params_repr.items():
            f.write(f"{k}:{v}")
# Out:
# Settings unchanged. Found existing setup in /scratch/zhaoyuha/Datas/EQuantum_data/dotgate_center_g/setup/setup_e2db2e7eecccbfe388a3974f304b0862. Skipping generation.

# %% [markdown]
# ## Initialized Setup

# %%
setuppathupdate=hash_folder
config_file=setuppathupdate+"/updated_sites_dot.json"
syst=System(geoparams,config_file=config_file,ifqsystem=True,quantum_builder="default")
# Out:
# Generated 144180 points in 3D.
# Voronoi cells have been created.
# 0 sites have been removed from the system.
# Vacuum pruning: removed 66154 sites
# The quantum system has been built using the default solver.
# Quantum system is generated using default.
# EQsystem is successfully initialized.

# %%
syst.plot_geometry(material='Qsystem',prop='potential')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Initialize without blender setup (dot)

# %%
syst=System(geoparams,ifqsystem=True,quantum_builder="default")
# Out:
# Generated 42315 points in 3D.
# Voronoi cells have been created.
# 1 sites have been removed from the system.
# Quantum system is generated using default.
# EQsystem is successfully initialized.

# %% [markdown]
# ## Initialize Quantum problem

# %%
qparams={'Ufunc': lambda x:0,'phi':0.08}
fsc=FSC(syst,ifinitial=False,qparams=qparams,approx="TF")
# Out:
# 🔄 Full Hamiltonian rebuild (qparams change)
# site_map: 0.001475905068218708
# update_U: 0.05893935402855277
# LDOS is calculated through kpm as a whole system.
# update_ildos: 0.8328550660517067
# alloc+fill: 0.017450376180931926
# copy back: 0.025692820083349943

# %%
boundary_condition={
    'gate': {'potential': -2},
    'dielectric': {'dielectric_constant': 4},
    'backgate': {'potential': 2.5}}
fsc.update_BC(updates=boundary_condition,ifinitial=True)
# Out:
# The poisson problem has been initialized.

# %% [markdown]
# ## Check the Spectrum

# %%
fsc.plot_Hamiltonian()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ltest = qbuilder.update_ildos(
    fsc, syst,
    approx="ED",
    eta=0.0001,
    Ncore=20,
    M=512,
    eps=0.05,
    kernel="jackson",
)
# Out:
# LDOS is calculated with ED method.

# %%
Htest=fsc.qsystem.get_hamiltonian().toarray()
evals,evecs=sl.eigh(Htest)

# %%
ErangeT=np.linspace(emin,emax,int(fsc.qsystem.N/2))

# %%
emin,emax=fsc.qsystem.get_energy_bounds()

# %%
weights=np.abs(evecs)**2

# %%
dE=ErangeT[None,:]-evals[:,None]
eta=0.0003
kernal=np.exp(-0.5*(dE/eta)**2)/(np.sqrt(2*np.pi)*eta)

# %%
fsc.t/20
# Out:
# 0.0001263675660416206

# %%
rho_all=weights@kernal

# %%
plt.figure()
plt.plot(ErangeT,rho_all[300,:])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.plot(ltest[1][0],ltest[1][1])
for ii in range(0,len(ltest),20):
    plt.plot(ltest[ii][0],[np.sum(ltest[ii][1][:idx]) for idx in range(len(ltest[ii][0]))])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
E = np.asarray(ildos[0], dtype=float)
rho = np.asarray(ildos[1], dtype=float)

n_from_ldos = np.trapz(rho, E)
print("Integrated LDOS =", n_from_ldos)
print("ni =", ni)
print("max_fill =", fsc.max_fill)
# Out:
# Integrated LDOS = 313.2586733495183
# ni = -168.444224033846
# max_fill = 313.25867334951835

# %%
plt.figure()
plt.plot(x_dis,y_dis)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
site_id
# Out:
# 22171

# %%
np.where(np.array(fsc.Qsites) == 40145)[0][0]
# Out:
# 4581

# %%
qidx = 4581  # index in Qprime

site_id = fsc.Qprime[qidx]
sidx = np.where(np.array(fsc.Qsites) == site_id)[0][0]

ni = fsc.ni[site_id]
Ci = fsc.Ci[qidx]
ildos = fsc.ildos[sidx]
Ui = fsc.Ui[site_id]

x_dis = np.asarray(ildos[0], dtype=float) - Ui
y_dis = np.asarray(ildos[1], dtype=float)

# cumulative integral using trapezoidal rule
ildos_dis = np.zeros_like(y_dis, dtype=float)
ildos_dis[1:] = np.cumsum(0.5 * (y_dis[1:] + y_dis[:-1]) * np.diff(x_dis))

ildos_interp = interp1d(
    x_dis,
    ildos_dis,
    kind='linear',
    fill_value='extrapolate',
    bounds_error=False
)

def dn_for_Ci(dU):
    return dU * Ci + ni

def diff(dU):
    return np.abs(dn_for_Ci(dU) - ildos_interp(dU))
def F(dU):
    return ni + Ci * dU - ildos_interp(dU)


limits = (float(np.min(x_dis)), float(np.max(x_dis)))

a, b = limits

try:
    Fa, Fb = F(a), F(b)
    if np.isfinite(Fa) and np.isfinite(Fb) and Fa * Fb <= 0:
        dUsol = brentq(F, a, b)
    else:
        res = minimize_scalar(lambda u: abs(F(u)), bounds=limits, method="bounded")
        dUsol = res.x
except Exception:
    res = minimize_scalar(lambda u: abs(F(u)), bounds=limits, method="bounded")
    dUsol = res.x

print(dUsol)
print(Ci*dUsol)
plt.figure(figsize=(8, 5))
plt.plot(x_dis, [dn_for_Ci(dU) for dU in x_dis], label="Poisson prediction")
plt.plot(x_dis, ildos_dis, label="Integrated LDOS")
#plt.plot(x_dis, [diff(dU) for dU in x_dis], label="Mismatch")
plt.xlabel(r"$\Delta U$")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 0.013710052148050487
# -0.0038977916698521155
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
E = np.asarray(fsc.ildos[sidx][0], dtype=float)
rho = np.asarray(fsc.ildos[sidx][1], dtype=float)

print("Integral =", np.trapz(rho, E))
print("max_fill =", fsc.max_fill)
# Out:
# Integral = 2.138334330331947
# max_fill = 2.138334330331947

# %%
syst.lat_spacing
# Out:
# 0.03

# %%
fsc.get_energy_bounds()[1]/fsc.t
# Out:
# 10.812728895330242

# %%
fsc.plot_qsystem(fsc.Ui[fsc.Qsites])
print(np.mean(fsc.Ui[fsc.Qsites]))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# -0.0021738937848903945

# %%
E = np.asarray(ildos[0], dtype=float)
rho = np.asarray(ildos[1], dtype=float)
print(np.trapz(rho, E), fsc.max_fill)
# Out:
# 313.2586733495183 313.25867334951835

# %%
Htest=fsc.qsystem.H.toarray()
pot=np.diagonal(Htest)

# %%
ev=np.sort(sl.eigvals(Htest))

# %%
ildos=qbuilder.update_ildos(
    fsc, syst,
    approx="TF",
    Ncore=20,
    M=512,
    eps=0.05,
    kernel="jackson",
)

# %%
nden=np.array([np.sum(ildos[0][1][:idx])for idx,ee in enumerate(ildos[0][0])])
plt.figure()
plt.plot(np.linspace(0,1,len(ev)),ev,label='ED')
#plt.plot(nden/nden[-1],ildos[0][0]-fsc.energy_bounds,label='kpm')
plt.legend()
plt.show()
# Out:
# /scratch/zhaoyuha/miniconda3/envs/equant/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Plot System

# %%
syst.plot_geometry(prop='potential',material='gate')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
gateidx=np.zeros(fsc.num_sites)
for qidx, site in enumerate(fsc.sites.values()): #for all sites in the quantum system
    if site.material=='Qsystem':
        gateidx[qidx]=fsc.Ui[qidx]
gateidx[gateidx==0]='nan'

# %%
indicate=np.zeros(len(fsc.sites))
indicate[fsc.D_indices]=1
fsc.plot_full(gateidx)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
num_neighbor=np.zeros(fsc.num_sites)
for qidx, idx in enumerate(fsc.Qsites): #for all sites in the quantum system
    for neighbor in fsc.sites[idx].neighbors:
        if fsc.sites[neighbor].material=='gate':  # if the neighboring sites also belongs to the Qsystem
            num_neighbor[idx]+=1

# %%
indicate=np.zeros(len(fsc.Qsites))
for idx in cut_idx:
    indicate[idx]=fsc.ni[fsc.Qprime][idx]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [196], in <cell line: 2>()
#       1 indicate=np.zeros(len(fsc.Qsites))
#       2 for idx in cut_idx:
# ----> 3     indicate[idx]=fsc.ni[fsc.Qprime][idx]
#
# IndexError: index 7373 is out of bounds for axis 0 with size 7321

# %%
for neighbor in fsc.sites[fsc.Qsites[2370]].neighbors:
    print(fsc.sites[neighbor].material)
# Out:
# Qsystem
# dielectric
# dielectric
# Qsystem
# Qsystem

# %%
indicate=np.zeros(fsc.num_sites)
for idx, qidx in enumerate(fsc.Qprime):
    indicate[qidx]=fsc.Ci[idx]

# %%
#indicate=np.zeros(fsc.num_sites)
#indicate[fsc.Qprime[1929]]=1
plotdata=Uis[1,:][fsc.Qsites]
#plotdata=dUdn[1]
#plotdata=pot
fsc.plot_qsystem(np.log(plotdata))
# Out:
# /tmp/ipykernel_1024784/828773061.py:6: RuntimeWarning: invalid value encountered in log
#   fsc.plot_qsystem(np.log(plotdata))
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
cut_idx=[idx for idx in range(len(fsc.Qsites)) if np.abs(fsc.sites[fsc.Qsites[idx]].coordinates[0])<0.002 and fsc.sites[fsc.Qsites[idx]].material=='Qsystem']
plt.figure()
plt.plot(Uis[-1,:][fsc.Qsites][cut_idx],'.-')
plt.plot(fsc.ni[fsc.Qsites][cut_idx],'.-')
#plt.plot(fsc.Ci[cut_idx])
plt.ylim([-0.75,2*fsc.bandwidth])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
cut_idx=[idx for idx in range(len(fsc.Qsites)) if np.abs(fsc.sites[fsc.Qsites[idx]].coordinates[0])<0.005 and fsc.sites[fsc.Qsites[idx]].material=='Qsystem']
plt.figure()
plt.plot(fsc.Ui[fsc.Qsites][cut_idx])
plt.plot(fsc.ni[fsc.Qsites][cut_idx])
#plt.plot(fsc.Ci[cut_idx])
plt.ylim([-0.01,fsc.bandwidth])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
cut_idx=[idx for idx in range(len(fsc.Qprime)) if np.abs(fsc.sites[fsc.Qprime[idx]].coordinates[0])<0.002 and fsc.sites[fsc.Qprime[idx]].material=='Qsystem']
plt.figure()
plt.plot(Uis[-1,:][fsc.Qprime][cut_idx])
plt.plot(fsc.ni[fsc.Qprime][cut_idx])
plt.plot(0.1*fsc.Ci[cut_idx])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
#plt.plot(fsc.Ui[fsc.Qprime][cut_idx])
#plt.plot(fsc.ni[fsc.Qprime][cut_idx])
plt.plot(fsc.Ci)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Solve FSC

# %%
fsc.local_solver()
# Out:
# 0.0016781762807804067 -0.0003229892056477772

# %%
fsc.ni
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
fsc.Ncore=20
fsc.convergence_tol=[3e-3,1e-2]
fsc.solve(
    syst,
    save=True,
    snapshot_mode="step",
    snapshot_every=1,
    snapshot_folder=setuppathupdate+"/fsc_logs_ED_e_6_alpha_0.4",
    save_ildos=True,
    ldos_method="ED",
    eta=0.0008,
    #M=256,
    #eps=0.05,
    #kernel="jackson",
)
# Out:
# Iteration counts [Step I, Step II, Step III]: [0, 0, 0]
# Solver streak: None, 0
#
# --- Iteration 0 ---
# Qprime size   : 8267
# max |Δn|      : 7.194e-13
# |Δn| per site  : 1.052e-14
# |Δn| per site % : -5.145e-14
# 1.5998354885128103 0.5366641905234937
# Iteration counts [Step I, Step II, Step III]: [0, 1, 0]
# Solver streak: poisson, 1
#
# --- Iteration 1 ---
# Qprime size   : 8267
# max |Δn|      : 5.642e-02
# |Δn| per site  : 4.286e-03
# |Δn| per site % : 3.671e-04
# last Poisson  : 18.422 s
# 0.9517035196866692 0.3131285828153705
# Iteration counts [Step I, Step II, Step III]: [0, 2, 0]
# Solver streak: poisson, 2
#
# --- Iteration 2 ---
# Qprime size   : 8267
# max |Δn|      : 6.930e-02
# |Δn| per site  : 2.920e-03
# |Δn| per site % : 2.497e-04
# last Poisson  : 18.121 s
# 0.5793743343500318 0.18840323012544918
# LDOS is calculated with ED method.
# Iteration counts [Step I, Step II, Step III]: [0, 2, 1]
# Solver streak: quantum, 1
#
# --- Iteration 3 ---
# Qprime size   : 8267
# max |Δn|      : 1.713e-02
# |Δn| per site  : 2.072e-03
# |Δn| per site % : 2.934e-03
# max |ΔILDOS|  : 1.089e+02
# |ΔILDOS| per site  : 2.212e+00
# |ΔILDOS| per site % : 1.808e+00
# last Poisson  : 18.121 s
# last Quantum  : 95.675 s
# 0.8336034468563901 0.30721435915624584
# Iteration counts [Step I, Step II, Step III]: [0, 3, 1]
# Solver streak: poisson, 1
#
# --- Iteration 4 ---
# Qprime size   : 8267
# max |Δn|      : 1.155e-01
# |Δn| per site  : 4.723e-03
# |Δn| per site % : 8.285e-04
# max |ΔILDOS|  : 1.089e+02
# |ΔILDOS| per site  : 2.212e+00
# |ΔILDOS| per site % : 1.808e+00
# last Poisson  : 17.862 s
# last Quantum  : 95.675 s
# 0.5205902140058499 0.18197496130627033
# LDOS is calculated with ED method.
# Iteration counts [Step I, Step II, Step III]: [0, 3, 2]
# Solver streak: quantum, 1
#
# --- Iteration 5 ---
# Qprime size   : 8267
# max |Δn|      : 2.293e-02
# |Δn| per site  : 2.001e-03
# |Δn| per site % : 2.668e-03
# max |ΔILDOS|  : 1.380e+02
# |ΔILDOS| per site  : 1.874e+00
# |ΔILDOS| per site % : 1.757e+09
# last Poisson  : 17.862 s
# last Quantum  : 113.778 s
# 0.30594541998118097 0.10143286839423143
# LDOS is calculated with ED method.
# Iteration counts [Step I, Step II, Step III]: [0, 3, 3]
# Solver streak: quantum, 2
#
# --- Iteration 6 ---
# Qprime size   : 8267
# max |Δn|      : 9.748e-03
# |Δn| per site  : 1.116e-03
# |Δn| per site % : 1.239e-03
# max |ΔILDOS|  : 1.376e+02
# |ΔILDOS| per site  : 1.366e+00
# |ΔILDOS| per site % : 2.409e+04
# last Poisson  : 17.862 s
# last Quantum  : 112.401 s
# 0.2063457888059044 0.06685135967695266
# LDOS is calculated with ED method.
# Iteration counts [Step I, Step II, Step III]: [0, 3, 4]
# Solver streak: quantum, 3
#
# --- Iteration 7 ---
# Qprime size   : 8267
# max |Δn|      : 6.779e-03
# |Δn| per site  : 7.353e-04
# |Δn| per site % : 4.640e-04
# max |ΔILDOS|  : 6.234e+01
# |ΔILDOS| per site  : 4.742e-01
# |ΔILDOS| per site % : 4.939e-01
# last Poisson  : 17.862 s
# last Quantum  : 99.784 s
# 0.18747054881276928 0.0617665096657359
# LDOS is calculated with ED method.
# Iteration counts [Step I, Step II, Step III]: [0, 3, 5]
# Solver streak: quantum, 4
#
# --- Iteration 8 ---
# Qprime size   : 8267
# max |Δn|      : 6.764e-03
# |Δn| per site  : 6.793e-04
# |Δn| per site % : 2.730e-04
# max |ΔILDOS|  : 5.469e+01
# |ΔILDOS| per site  : 2.199e-01
# |ΔILDOS| per site % : 7.138e-02
# last Poisson  : 17.862 s
# last Quantum  : 124.283 s
# 0.19151058679117566 0.06319187631288817
# LDOS is calculated with ED method.
# Iteration counts [Step I, Step II, Step III]: [0, 3, 6]
# Solver streak: quantum, 5
#
# --- Iteration 9 ---
# Qprime size   : 8267
# max |Δn|      : 6.761e-03
# |Δn| per site  : 6.950e-04
# |Δn| per site % : 2.418e-04
# max |ΔILDOS|  : 1.661e+01
# |ΔILDOS| per site  : 1.612e-01
# |ΔILDOS| per site % : 3.492e-02
# last Poisson  : 17.862 s
# last Quantum  : 126.903 s
# 0.20055184418194666 0.06620687993618776
# Iteration counts [Step I, Step II, Step III]: [0, 4, 6]
# Solver streak: poisson, 1
#
# --- Iteration 10 ---
# Qprime size   : 8267
# max |Δn|      : 1.665e-01
# |Δn| per site  : 5.314e-03
# |Δn| per site % : 8.752e-04
# max |ΔILDOS|  : 1.661e+01
# |ΔILDOS| per site  : 1.612e-01
# |ΔILDOS| per site % : 3.492e-02
# last Poisson  : 18.268 s
# last Quantum  : 126.903 s
# 0.22840285754426068 0.07479454445500963
# LDOS is calculated with ED method.
# Iteration counts [Step I, Step II, Step III]: [0, 4, 7]
# Solver streak: quantum, 1
#
# --- Iteration 11 ---
# Qprime size   : 8267
# max |Δn|      : 8.112e-03
# |Δn| per site  : 8.226e-04
# |Δn| per site % : 3.686e-04
# max |ΔILDOS|  : 1.235e+02
# |ΔILDOS| per site  : 3.804e-01
# |ΔILDOS| per site % : 8.691e-02
# last Poisson  : 18.268 s
# last Quantum  : 109.028 s
# 0.23806755565196142 0.07825910139598662
# LDOS is calculated with ED method.
# Iteration counts [Step I, Step II, Step III]: [0, 4, 8]
# Solver streak: quantum, 2
#
# --- Iteration 12 ---
# Qprime size   : 8267
# max |Δn|      : 8.315e-03
# |Δn| per site  : 8.607e-04
# |Δn| per site % : 3.265e-04
# max |ΔILDOS|  : 6.791e+01
# |ΔILDOS| per site  : 2.513e-01
# |ΔILDOS| per site % : 5.369e-02
# last Poisson  : 18.268 s
# last Quantum  : 116.743 s
# 0.19617456054427176 0.06471967759014424
# LDOS is calculated with ED method.
# Iteration counts [Step I, Step II, Step III]: [0, 4, 9]
# Solver streak: quantum, 3
#
# --- Iteration 13 ---
# Qprime size   : 8267
# max |Δn|      : 6.235e-03
# |Δn| per site  : 7.118e-04
# |Δn| per site % : 2.590e-04
# max |ΔILDOS|  : 3.879e+01
# |ΔILDOS| per site  : 1.811e-01
# |ΔILDOS| per site % : 3.659e-02
# last Poisson  : 18.268 s
# last Quantum  : 104.424 s
# 0.18094031050482703 0.05984999579149072
# LDOS is calculated with ED method.
# Iteration counts [Step I, Step II, Step III]: [0, 4, 10]
# Solver streak: quantum, 4
#
# --- Iteration 14 ---
# Qprime size   : 8267
# max |Δn|      : 6.144e-03
# |Δn| per site  : 6.582e-04
# |Δn| per site % : 2.357e-04
# max |ΔILDOS|  : 1.279e+01
# |ΔILDOS| per site  : 1.580e-01
# |ΔILDOS| per site % : 3.236e-02
# last Poisson  : 18.268 s
# last Quantum  : 103.490 s
# 0.1765013030263413 0.05844343851249286
# LDOS is calculated with ED method.
# Iteration counts [Step I, Step II, Step III]: [0, 4, 11]
# Solver streak: quantum, 5
#
# --- Iteration 15 ---
# Qprime size   : 8267
# max |Δn|      : 6.019e-03
# |Δn| per site  : 6.428e-04
# |Δn| per site % : 2.303e-04
# max |ΔILDOS|  : 1.391e+01
# |ΔILDOS| per site  : 1.565e-01
# |ΔILDOS| per site % : 3.172e-02
# last Poisson  : 18.268 s
# last Quantum  : 88.925 s
# 0.1766534719166945 0.058545386617938865
# Iteration counts [Step I, Step II, Step III]: [0, 5, 11]
# Solver streak: poisson, 1
#
# --- Iteration 16 ---
# Qprime size   : 8267
# max |Δn|      : 3.327e-01
# |Δn| per site  : 1.097e-02
# |Δn| per site % : 1.540e-03
# max |ΔILDOS|  : 1.391e+01
# |ΔILDOS| per site  : 1.565e-01
# |ΔILDOS| per site % : 3.172e-02
# last Poisson  : 17.427 s
# last Quantum  : 88.925 s
# 0.4352414823847587 0.1415776852231987
# LDOS is calculated with ED method.
# Iteration counts [Step I, Step II, Step III]: [0, 5, 12]
# Solver streak: quantum, 1
#
# --- Iteration 17 ---
# Qprime size   : 8267
# max |Δn|      : 1.204e-02
# |Δn| per site  : 1.557e-03
# |Δn| per site % : 6.618e-04
# max |ΔILDOS|  : 8.881e+01
# |ΔILDOS| per site  : 4.104e-01
# |ΔILDOS| per site % : 1.171e-01
# last Poisson  : 17.427 s
# last Quantum  : 100.506 s
# 0.18092125197325334 0.05772726581091692
# LDOS is calculated with ED method.
# Iteration counts [Step I, Step II, Step III]: [0, 5, 13]
# Solver streak: quantum, 2
#
# --- Iteration 18 ---
# Qprime size   : 8267
# max |Δn|      : 6.050e-03
# |Δn| per site  : 6.349e-04
# |Δn| per site % : 2.578e-04
# max |ΔILDOS|  : 9.798e+01
# |ΔILDOS| per site  : 2.958e-01
# |ΔILDOS| per site % : 5.902e-02
# last Poisson  : 17.427 s
# last Quantum  : 121.703 s
# 0.11507979464343233 0.037787568371621415
# LDOS is calculated with ED method.
# Iteration counts [Step I, Step II, Step III]: [0, 5, 14]
# Solver streak: quantum, 3
#
# --- Iteration 19 ---
# Qprime size   : 8267
# max |Δn|      : 4.738e-03
# |Δn| per site  : 4.156e-04
# |Δn| per site % : 1.590e-04
# max |ΔILDOS|  : 9.801e+01
# |ΔILDOS| per site  : 2.290e-01
# |ΔILDOS| per site % : 3.232e-02
# last Poisson  : 17.427 s
# last Quantum  : 118.660 s
# 0.11271055646043197 0.03710979411854919
# LDOS is calculated with ED method.

# %%
testi=fsc.ildos.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 testi=fsc.ildos.copy()
#
# NameError: name 'fsc' is not defined

# %%
testi[:]

# %%
plt.figure()
plt.plot(testi[1000,0,:],testi[1000,1,:])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 plt.figure()
#       2 plt.plot(testi[1000,0,:],testi[1000,1,:])
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
np.abs(testi)
# Out:
# array([[[0.23934545, 0.23887753, 0.2384096 , ..., 0.2384096 ,
#          0.23887753, 0.23934545],
#         [0.        , 0.        , 0.        , ..., 0.        ,
#          0.        , 0.        ]],
#
#        [[0.23934545, 0.23887753, 0.2384096 , ..., 0.2384096 ,
#          0.23887753, 0.23934545],
#         [0.        , 0.        , 0.        , ..., 0.        ,
#          0.        , 0.        ]],
#
#        [[0.23934545, 0.23887753, 0.2384096 , ..., 0.2384096 ,
#          0.23887753, 0.23934545],
#         [0.        , 0.        , 0.        , ..., 0.        ,
#          0.        , 0.        ]],
#
#        ...,
#
#        [[0.23934545, 0.23887753, 0.2384096 , ..., 0.2384096 ,
#          0.23887753, 0.23934545],
#         [0.        , 0.        , 0.        , ..., 0.        ,
#          0.        , 0.        ]],
#
#        [[0.23934545, 0.23887753, 0.2384096 , ..., 0.2384096 ,
#          0.23887753, 0.23934545],
#         [0.        , 0.        , 0.        , ..., 0.        ,
#          0.        , 0.        ]],
#
#        [[0.23934545, 0.23887753, 0.2384096 , ..., 0.2384096 ,
#          0.23887753, 0.23934545],
#         [0.        , 0.        , 0.        , ..., 0.        ,
#          0.        , 0.        ]]])

# %%
import matplotlib.pyplot as plt
import numpy as np

ni_maxdiff = np.array(fsc.log.get("ildos_l2diff", []))
ni_l2diff  = np.array(fsc.log.get("ni_l2diff", []))

plt.figure(figsize=(6,4))

if len(ni_maxdiff):
    plt.plot(ni_maxdiff, label="max |Δn|")

if len(ni_l2diff):
    plt.plot(ni_l2diff, label="L2 |Δn|")

plt.yscale("log")
plt.xlabel("Iteration")
plt.ylabel("Δn")
plt.title("Density change per iteration")
plt.legend()
plt.grid(True)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
